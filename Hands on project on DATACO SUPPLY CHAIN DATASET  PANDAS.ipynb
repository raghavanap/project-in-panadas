# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\raghav\Downloads\DataCoSupplyChainDataset.csv')
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %% [markdown]
# # TO display number of rows and columns

# %%
df.shape
# Out:
# (180519, 53)

# %% [markdown]
# # Display datatype of all columns

# %%
df.dtypes
# Out:
# Type                              object
# Days for shipping (real)           int64
# Days for shipment (scheduled)      int64
# Benefit per order                float64
# Sales per customer               float64
# Delivery Status                   object
# Late_delivery_risk                 int64
# Category Id                        int64
# Category Name                     object
# Customer City                     object
# Customer Country                  object
# Customer Email                    object
# Customer Fname                    object
# Customer Id                        int64
# Customer Lname                    object
# Customer Password                 object
# Customer Segment                  object
# Customer State                    object
# Customer Street                   object
# Customer Zipcode                 float64
# Department Id                      int64
# Department Name                   object
# Latitude                         float64
# ...

# %% [markdown]
# # Display all column names

# %%
df.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.count()
# Out:
# Type                             180519
# Days for shipping (real)         180519
# Days for shipment (scheduled)    180519
# Benefit per order                180519
# Sales per customer               180519
# Delivery Status                  180519
# Late_delivery_risk               180519
# Category Id                      180519
# Category Name                    180519
# Customer City                    180519
# Customer Country                 180519
# Customer Email                   180519
# Customer Fname                   180519
# Customer Id                      180519
# Customer Lname                   180511
# Customer Password                180519
# Customer Segment                 180519
# Customer State                   180519
# Customer Street                  180519
# Customer Zipcode                 180516
# Department Id                    180519
# Department Name                  180519
# Latitude                         180519
# ...

# %% [markdown]
# # Join cust_first_name and last_name as cust_name

# %%
df['cust_name']=df['Customer Fname']+ ' ' + df['Customer Lname']
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %% [markdown]
# # to display the empty values in DF

# %%
df.isnull().sum()
# Out:
# Type                                  0
# Days for shipping (real)              0
# Days for shipment (scheduled)         0
# Benefit per order                     0
# Sales per customer                    0
# Delivery Status                       0
# Late_delivery_risk                    0
# Category Id                           0
# Category Name                         0
# Customer City                         0
# Customer Country                      0
# Customer Email                        0
# Customer Fname                        0
# Customer Id                           0
# Customer Lname                        8
# Customer Password                     0
# Customer Segment                      0
# Customer State                        0
# Customer Street                       0
# Customer Zipcode                      3
# Department Id                         0
# Department Name                       0
# Latitude                              0
# ...

# %% [markdown]
# #to display the count of NaN values in DF

# %%
pd.set_option('display.max_columns',85)
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  \
# 0                   0           73  Sporting Goods        Caguas
# ...

# %% [markdown]
# # splitting of customer street into cust_street_code and cust_street_name

# %%
df[['cust_street_code','cust_street_name']]=df['Customer Street'].str.split(' ',n=1,expand=True)
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  \
# 0                   0           73  Sporting Goods        Caguas
# ...

# %% [markdown]
# # which shipping mode is most preferred by each country?

# %%
df['Order Country'].groupby(df['Shipping Mode']).value_counts()
# Out:
# Shipping Mode   Order Country
# First Class     Estados Unidos       3824
#                 Francia              2043
#                 M�xico               2017
#                 Alemania             1580
#                 Brasil               1242
#                                      ...
# Standard Class  Kuwait                  2
#                 S�hara Occidental       2
#                 Burundi                 1
#                 Serbia                  1
#                 Tayikist�n              1
# Name: Order Country, Length: 560, dtype: int64

# %% [markdown]
# # which prod_category is having highest benefit per order

# %%
df.groupby('Category Name').agg({'Benefit per order':'max'}).sort_values(by='Benefit per order', ascending=False).iloc[:1]
# Out:
#                    Benefit per order
# Category Name
# Strength Training         911.799988

# %%
df.groupby('Category Name').agg({'Benefit per order':'max'})['Benefit per order'].nlargest(1)
# Out:
# Category Name
# Strength Training    911.799988
# Name: Benefit per order, dtype: float64

# %% [markdown]
# # which city is having highest customer?

# %%
df['Customer City'].groupby(df['Customer Zipcode']).value_counts().nlargest(10)
# Out:
# Customer Zipcode  Customer City
# 725.0             Caguas             66770
# 921.0             San Juan             337
# 23455.0           Virginia Beach       334
# 957.0             Bayamon              297
# 79109.0           Amarillo             292
# 33324.0           Fort Lauderdale      283
# 80012.0           Aurora               280
# 33624.0           Tampa                261
# 92115.0           San Diego            256
# 92024.0           Encinitas            254
# Name: Customer City, dtype: int64

# %%
df['Order Status']=='PENDING'
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 180514    False
# 180515    False
# 180516     True
# 180517    False
# 180518    False
# Name: Order Status, Length: 180519, dtype: bool

# %%
df['Product Card Id']df['Order Item Discount'].max()
# Out:
#   File "<ipython-input-19-fa7e5486cce8>", line 1
#     df['Product Card Id']df['Order Item Discount'].max()
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # converting order_date and shiping_date into one format

# %%
df['order date (DateOrders)'] = pd.to_datetime(df['order date (DateOrders)'])
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
df['shipping date (DateOrders)'] = pd.to_datetime(df['shipping date (DateOrders)'])
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  \
# 0                   0           73  Sporting Goods        Caguas
# ...

# %% [markdown]
# # which country is having most suspected fraud

# %%
df[('Order Country')][(df['Order Status']=='SUSPECTED_FRAUD')].value_counts().head(1)
# Out:
# Estados Unidos    573
# Name: Order Country, dtype: int64

# %% [markdown]
# # no of pending order status in the city w.r. to India

# %%
df['Order City'][(df['Order Status']=='PENDING')& (df['Order Country']=='India' )]
# Out:
# 1             Bikaner
# 21           Jabalpur
# 45          Bangalore
# 46          Bangalore
# 382              Pune
#              ...
# 180142    Bhubaneswar
# 180164           Agra
# 180248          Dewas
# 180331          Ajmer
# 180405          Patna
# Name: Order City, Length: 537, dtype: object

# %% [markdown]
# # which product has maximum discount

# %%
df['Product Name'][df['Order Item Discount']==df['Order Item Discount'].max()]
# Out:
# 12606    SOLE E35 Elliptical
# Name: Product Name, dtype: object

# %% [markdown]
# # which year min sales for NIKE products

# %%
nike=df['Product Name'].str.contains('Nike',na=False)
df.loc[nike,'Product Price'].sum()
# Out:
# 5247620.386644341

# %%
df.loc[nike,'Product Name']
df.head()
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  \
# 0                   0           73  Sporting Goods        Caguas
# ...

# %%
d = sales['order date (DateOrders)']
order date (DateOrders).groupby([d.dt.year.rename('Year'), d.dt.month.rename('Month')]).sum()
# Out:
#   File "<ipython-input-69-e72b44ba8a13>", line 2
#     order date (DateOrders).groupby([d.dt.year.rename('Year'), d.dt.month.rename('Month')]).sum()
#           ^
# SyntaxError: invalid syntax
